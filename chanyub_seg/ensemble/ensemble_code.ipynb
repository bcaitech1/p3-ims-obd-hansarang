# %%
import numpy as np
from collections import Counter
from tqdm.notebook import tqdm

# %%
current_path = '/content/drive/MyDrive/Trash/ensemble'
park = np.load('{}/park.npy'.format(current_path))
cho = np.load('{}/cho.npy'.format(current_path))
heo = np.load('{}/heo.npy'.format(current_path),allow_pickle=True)
tak = np.load('{}/tak.npy'.format(current_path))
song = np.load('{}/song.npy'.format(current_path))
shin = np.load('{}/shin.npy'.format(current_path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-1ea9bdff57d5> in <module>()
#       2 park = np.load('{}/park.npy'.format(current_path))
#       3 cho = np.load('{}/cho.npy'.format(current_path))
# ----> 4 heo = np.load('{}/heo.npy'.format(current_path),allow_pickle=True)
#       5 tak = np.load('{}/tak.npy'.format(current_path))
#       6 song = np.load('{}/song.npy'.format(current_path))
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Trash/ensemble/heo.npy'

# %%
len(park[9])
# Out:
# 65536

# %%
def modefinder(numbers_tuple):
  c = Counter(numbers_tuple)
  mode = c.most_common(1)
  # return mode
  return mode[0][0] # [0][0] 이라고 하는 이유 : most_common 출력이 [(0,4)] 이런식임 => "0이 4표다."

# %%
ensemble = [[0 for x in range(65536)] for y in range (837)]

for i in tqdm(range(837)) :
  for j in range (65536) :
    candidates = (cho[i][j], park[i][j], heo[i][j], tak[i][j], song[i][j], shin[i][j]) #리더보드순 정렬
    # candidates_test = (cho[i][j], cho[i][j]+1, cho[i][j]+2, cho[i][j]+2, cho[i][j]+2)
    # print(modefinder(candidates))
    ensemble[i][j] = modefinder(candidates)
    # print(modefinder(candidates_test))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=837.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-2447a640c8ae> in <module>()
#       6     # candidates_test = (cho[i][j], cho[i][j]+1, cho[i][j]+2, cho[i][j]+2, cho[i][j]+2)
#       7     # print(modefinder(candidates))
# ----> 8     ensemble[i][j] = modefinder(candidates)
#       9     # print(modefinder(candidates_test))
#
# <ipython-input-91-a49c1ebc0aa8> in modefinder(numbers_tuple)
#       1 def modefinder(numbers_tuple):
# ----> 2   c = Counter(numbers_tuple)
#       3   mode = c.most_common(1)
#       4   # return mode
#       5   return mode[0][0] # [0][0] 이라고 하는 이유 : most_common 출력이 [(0,4)] 이런식임 => "0이 4표다."
#
# /usr/lib/python3.7/collections/__init__.py in __init__(*args, **kwds)
#     565         if len(args) > 1:
#     566             raise TypeError('expected at most 1 arguments, got %d' % len(args))
# --> 567         super(Counter, self).__init__()
#     568         self.update(*args, **kwds)
#     569
#
# KeyboardInterrupt:
